# %%
from IPython.display import display
from PIL import Image
from io import BytesIO
import requests
import json
import app as np


def show_news(news):
    if len(news) < 1:
        return "No news found"
    if len(news) < 5:
        for i in range(0,len(news)):
            print(news[i]["title"])
            print(news[i]["content"])
            print(news[i]["url"])
            print(news[i]["publishedAt"])
            print(news[i]["source"]["name"])
            #print(news[i]["urlToImage"])
            #display(Image(news[i]["urlToImage"]))
            #get_image(news[i]["urlToImage"])
            display(np.get_image(news[i]["urlToImage"]))
    for i in range(0,5):
        print(news[i]["title"])
        print(news[i]["content"])
        print(news[i]["url"])
        print(news[i]["publishedAt"])
        print(news[i]["source"]["name"])
        #print(news[i]["urlToImage"])
        #display(Image(news[i]["urlToImage"]))
        display(np.get_image(news[i]["urlToImage"]))

#show_news(news)

# %%
show_news(np.news_source("fox-news"))
# Out:
# Ukraine invasion: Russia 'increasingly frustrated' by lack of momentum: US defense official
# As Ukraine enters its third day of Russian bombardment following President Vladimir Putins invasion this week, a senior defense official said Saturday that Moscow has become "increasingly frustrated"… [+3349 chars]
# https://www.foxnews.com/politics/ukraine-invasion-russia-increasingly-frustrated-lack-of-momentum-us-defense-official
# 2022-02-26T16:07:22.9508416Z
# Fox News
# <PIL.Image.Image image mode=RGBA size=300x200 at 0x113CA7F70>
# Ukrainian President Zelenskyy has true ‘courage, leadership’: Rep. Jordan
# None
# https://video.foxnews.com/v/6298966237001/
# 2022-02-26T15:37:14.6074036Z
# Fox News
# <PIL.Image.Image image mode=RGB size=300x200 at 0x114ADAAC0>
# US tech company in Ukraine: Employees volunteer to fight Russia
# A handful of San Francisco-based JustAnswer employees in Ukraine immediately volunteered to join Ukraine's military in defending the nation against Russian forces, CEO Andy Kurtzig told FOX Business.… [+2217 chars]
# https://www.foxbusiness.com/lifestyle/justanswer-ukraine-invasion-tech-company-employees-fighting
# 2022-02-26T15:07:20.7798207Z
# Fox News
# <PIL.Image.Image image mode=RGB size=300x200 at 0x113CBCEE0>
# Ukraine to get $350M more in US defense aid, including anti-armor, small arms, munitions
# The U.S. will further bolster Ukraine's defense in the face of Russian invasion with an unprecedented third payment of $350 million, Secretary of StateAntony Blinken announced Saturday.
# The defense … [+2189 chars]
# https://www.foxnews.com/world/ukraine-russia-350-million-payment-defense-support
# 2022-02-26T14:52:20.0919386Z
# Fox News
# <PIL.Image.Image image mode=RGB size=300x200 at 0x113CA7520>
# Ukrainian government pressing West for more weapons, sanctions
# None
# https://video.foxnews.com/v/6298957919001/
# 2022-02-26T14:37:17.3740106Z
# Fox News
# <PIL.Image.Image image mode=RGB size=300x200 at 0x113CA7520>

# %%
show_news(np.news_source("cnn"))
# Out:
# Video: 'Don't trust Putin': Ukraine's former president speaks to CNN from streets - CNN Video
# None
# http://us.cnn.com/videos/world/2022/02/26/petro-poroshenko-dont-trust-putin-ukraine-russia-nr-vpx.cnn
# 2022-02-26T16:07:27.2642319Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x113CA7E80>
# Inside Biden's decision to pick Ketanji Brown Jackson for Supreme Court
# (CNN)President Joe Biden's choice of Ketanji Brown Jackson for the Supreme Court came about like so many of his big decisions: after a long process, with a lot of wavering and discussion, and ultimat… [+7794 chars]
# http://us.cnn.com/2022/02/26/politics/ketanji-brown-jackson-biden-scotus-pick/index.html
# 2022-02-26T14:49:06Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x110B97580>
# Zelensky refuses US offer to evacuate, saying 'I need ammunition, not a ride'
# None
# https://www.cnn.com/2022/02/26/europe/ukraine-zelensky-evacuation-intl/index.html
# 2022-02-26T13:10:58Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x114ABEFD0>
# US lobbying firms rush to cut ties with Russian businesses hit with sanctions
# In the years leading up to Russias attack on Ukraine, US lobbyists have raked in millions of dollars from Russian banks and financial firms paying to push their interests in Washington.
# Now, in the … [+9866 chars]
# http://us.cnn.com/2022/02/26/politics/lobbying-firms-russian-businesses-sanctions-invs/index.html
# 2022-02-26T13:05:59Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x110B569D0>
# Video shows missile or rocket striking building in Kyiv, Ukraine - CNN Video
# None
# http://us.cnn.com/videos/world/2022/02/26/missile-hits-building-kyiv-newday-vpx.cnn
# 2022-02-26T12:52:23.4826589Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x114ADAE20>

# %%
show_news(np.news_source("nyt-news"))
# Out:
# 'No news found'
