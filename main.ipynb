# %%
from IPython.display import display
from PIL import Image
from io import BytesIO
import requests
import json
import app as np


def show_news(news,n = 5):
    if len(news) < 1:
        return "No news found"
    if len(news) < n:
        for i in range(0,len(news)):
            print(news[i]["title"])
            print(news[i]["content"])
            print(news[i]["url"])
            print(news[i]["publishedAt"])
            print(news[i]["source"]["name"])
            #print(news[i]["urlToImage"])
            #display(Image(news[i]["urlToImage"]))
            #get_image(news[i]["urlToImage"])
            display(np.get_image(news[i]["urlToImage"]))
    for i in range(0,n):
        print(news[i]["title"])
        print(news[i]["content"])
        print(news[i]["url"])
        print(news[i]["publishedAt"])
        print(news[i]["source"]["name"])
        #print(news[i]["urlToImage"])
        #display(Image(news[i]["urlToImage"]))
        display(np.get_image(news[i]["urlToImage"]))

#show_news(news)


def run(source = '',range = 5):
    show_news(np.news_source(source),range)

# %%
run('cnn')
# Out:
# 'Remarkable': CNN reporter spots major Russian tank movement on live tv - CNN Video
# None
# http://us.cnn.com/videos/world/2022/02/26/russian-tanks-ukraine-video-pleitgen-vpx.cnn
# 2022-02-26T17:07:29.5316622Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x109085220>
# Video: 'Don't trust Putin': Ukraine's former president speaks to CNN from streets - CNN Video
# None
# http://us.cnn.com/videos/world/2022/02/26/petro-poroshenko-dont-trust-putin-ukraine-russia-nr-vpx.cnn
# 2022-02-26T16:07:27.2642319Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x1090A86D0>
# Inside Biden's decision to pick Ketanji Brown Jackson for Supreme Court
# (CNN)President Joe Biden's choice of Ketanji Brown Jackson for the Supreme Court came about like so many of his big decisions: after a long process, with a lot of wavering and discussion, and ultimat… [+7794 chars]
# http://us.cnn.com/2022/02/26/politics/ketanji-brown-jackson-biden-scotus-pick/index.html
# 2022-02-26T14:49:06Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x10944B580>
# Zelensky refuses US offer to evacuate, saying 'I need ammunition, not a ride'
# None
# https://www.cnn.com/2022/02/26/europe/ukraine-zelensky-evacuation-intl/index.html
# 2022-02-26T13:10:58Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x10945FD90>
# US lobbying firms rush to cut ties with Russian businesses hit with sanctions
# In the years leading up to Russias attack on Ukraine, US lobbyists have raked in millions of dollars from Russian banks and financial firms paying to push their interests in Washington.
# Now, in the … [+9866 chars]
# http://us.cnn.com/2022/02/26/politics/lobbying-firms-russian-businesses-sanctions-invs/index.html
# 2022-02-26T13:05:59Z
# CNN
# <PIL.Image.Image image mode=RGB size=300x200 at 0x1088E4F40>

# %%
run('bbc-news',10)
# Out:
# Ukraine conflict: Refugees rush to borders to flee Russia's war
# Image caption, The majority of Ukrainians fleeing Ukraine into Hungary are women and children
# Refugee agencies fear up to five million of Ukrainians could try to flee across the border as Russia's w… [+5638 chars]
# http://www.bbc.co.uk/news/world-europe-60527138
# 2022-02-26T17:22:22.4051528Z
# BBC News
# <PIL.Image.Image image mode=RGB size=300x200 at 0x10A92CB50>
# Ukraine: France seizes Russian ship over sanctions
# Image caption, The Baltic Leader ship is being held in Boulogne
# French sea police have impounded a Russian-flagged cargo ship suspected of breaching sanctions imposed because of the Ukraine war.
# T… [+751 chars]
# http://www.bbc.co.uk/news/world-europe-60539119
# 2022-02-26T16:07:28.8107214Z
# BBC News
# <PIL.Image.Image image mode=RGB size=300x200 at 0x